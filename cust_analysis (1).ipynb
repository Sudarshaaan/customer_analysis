# %% [markdown]
# # Download CSV Files & Load Data into SQL

# %% [markdown]
# ### We have used mysql-connector to connect the db with python

# %%
import mysql.connector
connection = mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="Sudarshan777",  
    database="customer_behaviour_analysis"
)
cursor = connection.cursor()
cursor.execute("SELECT DATABASE();")
db_name = cursor.fetchone()
print(f"Connected to database: {db_name[0]}")
cursor.close()
connection.close()
# Out:
# Connected to database: customer_behaviour_analysis

# %% [markdown]
# # Load and Display Datasets in Tables

# %% [markdown]
# ### Each dataset is loaded using pd.read_csv()

# %%
import pandas as pd
from IPython.display import display
c = pd.read_csv('customers.csv')
cr = pd.read_csv('customer_reviews.csv')
j = pd.read_csv('customer_journey.csv')
e = pd.read_csv('engagement_data.csv')
p = pd.read_csv('products.csv')
g = pd.read_csv('geography.csv')
print("Customers Table")
display(c.head()) 

print("Customer Reviews Table")
display(cr.head())

print("Customer Journey Table")
display(j.head())

print("Engagement Data Table")
display(e.head())

print("Products Table")
display(p.head())

print("Geography Table")
display(g.head())
# Out:
# Customers Table
#    CustomerID      CustomerName                         Email  Gender  Age  \
# 0           1     Emma Anderson     emma.anderson@example.com    Male   50
# 1           2       Sarah Brown       sarah.brown@example.com  Female   37
# 2           3  Robert Hernandez  robert.hernandez@example.com  Female   26
# 3           4      David Garcia      david.garcia@example.com    Male   25
# 4           5       Emma Miller       emma.miller@example.com  Female   41
#
#    GeographyID
# 0            2
# 1            4
# 2            6
# 3            8
# 4            4
# Customer Reviews Table
#    ReviewID  CustomerID  ProductID  ReviewDate  Rating  \
# 0         1          77         18  2023-12-23       3
# 1         2          80         19  2024-12-25       5
# 2         3          50         13  2025-01-26       4
# 3         4          78         15  2025-04-21       3
# 4         5          64          2  2023-07-16       3
#
# ...

# %% [markdown]
# # Executing the SQL Queries Using Python

# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine('mysql+mysqlconnector://root:Sudarshan777@127.0.0.1/customer_behaviour_analysis')

query = """
    SELECT 
        c.CustomerID, c.CustomerName, c.Age, g.Country, 
        p.ProductName, cr.Rating, j.Stage, j.Action, j.Duration
    FROM 
        customers c
    JOIN 
        geography g ON c.GeographyID = g.GeographyID
    JOIN 
        customer_journey j ON c.CustomerID = j.CustomerID
    JOIN 
        customer_reviews cr ON c.CustomerID = cr.CustomerID
    JOIN 
        products p ON p.ProductID = cr.ProductID;
"""
df = pd.read_sql(query, engine)
print(df.head())
# Out:
#    CustomerID    CustomerName  Age  Country      ProductName  Rating  \
# 0          64  Sarah Martinez   62  Belgium    Tennis Racket       3
# 1          64  Sarah Martinez   62  Belgium  Fitness Tracker       3
# 2          94   Jane Anderson   48  Belgium            Kayak       4
# 3          34   Daniel Miller   57   France     Swim Goggles       4
# 4          34   Daniel Miller   57   France    Tennis Racket       1
#
#          Stage    Action Duration
# 0     Checkout  Drop-off
# 1     Checkout  Drop-off
# 2     Checkout  Drop-off
# 3  ProductPage      View    235.0
# 4  ProductPage      View    235.0

# %%
# Out:
# <style type="text/css">
# #T_36b44 th {
#   background-color: lightgray;
# }
# </style>
# <table id="T_36b44">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36b44_level0_col0" class="col_heading level0 col0" >CustomerID</th>
#       <th id="T_36b44_level0_col1" class="col_heading level0 col1" >CustomerName</th>
#       <th id="T_36b44_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_36b44_level0_col3" class="col_heading level0 col3" >Country</th>
#       <th id="T_36b44_level0_col4" class="col_heading level0 col4" >ProductName</th>
#       <th id="T_36b44_level0_col5" class="col_heading level0 col5" >Rating</th>
#       <th id="T_36b44_level0_col6" class="col_heading level0 col6" >Stage</th>
#       <th id="T_36b44_level0_col7" class="col_heading level0 col7" >Action</th>
#       <th id="T_36b44_level0_col8" class="col_heading level0 col8" >Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...
